# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\DELL\Documents\vscode_simplon\la_peche_NILE_LEPRECHAUNS\data\raw\operations.csv")
df.head()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_25040\2196070199.py:1: DtypeWarning: Columns (1,2,11,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r"C:\Users\DELL\Documents\vscode_simplon\la_peche_NILE_LEPRECHAUNS\data\raw\operations.csv")
#    operation_id type_operation pourquoi_alerte              moyen_alerte  \
# 0       -135614            MAS             NaN                VHF phonie
# 1       -135613            SAR             NaN  Téléphone mobile à terre
# 2       -135598            MAS             NaN            Téléphone fixe
# 3       -135597            MAS             NaN                VHF phonie
# 4       -135596            SAR             NaN        Balise de détresse
#
#                            qui_alerte                  categorie_qui_alerte  \
# 0                     Navire impliqué                       Navire à la mer
# 1        CORG / Gendarmerie nationale  Autorité militaire française à terre
# ...

# %%
df['date_heure_fin_operation'].head()
# Out:
# 0    2025-06-12 00:55:00+00:00
# 1    2025-06-30 02:05:00+00:00
# 2    2025-06-13 23:08:00+00:00
# 3    2025-06-13 15:00:00+00:00
# 4    2025-06-13 21:48:00+00:00
# Name: date_heure_fin_operation, dtype: object
